# %% [markdown]
# <a href="https://colab.research.google.com/github/simranprajapati2/Microsoft-Training-2026/blob/main/Day2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Print statement

# %%
print("Hello World!", end=" ")
print("I will print on the same line.")
# Out:
# Hello World! I will print on the same line.

# %%
print(3)
print(358)
print(50000)
# Out:
# 3
# 358
# 50000

# %%
print("I am", 35, "years old.")
# Out:
# I am 35 years old.

# %%
print ('Welcome to Nirmaan')
# Out:
# Welcome to Nirmaan

# %%
print("Welcome to Nirman")
# Out:
# Welcome to Nirman

# %%
print("He's good")
# Out:
# He's good

# %%
print ('he's good')
# Out:
#   File "/tmp/ipykernel_2568/2682991968.py", line 1
#     print ('he's good')
#                      ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
print("welcom \n to \n nirmaaan")
# Out:
# welcom
#  to
#  nirmaaan

# %%
print("welcome","Nirmaan")
# Out:
# welcome Nirmaan

# %%
x = 1    # int
y = 2.8  # float
z = 1j   # complex

#convert from int to float:
a = float(x)

#convert from float to int:
b = int(y)

#convert from int to complex:
c = complex(x)

print(a)
print(b)
print(c)

print(type(a))
print(type(b))
print(type(c))
# Out:
# 1.0
# 2
# (1+0j)
# <class 'float'>
# <class 'int'>
# <class 'complex'>

# %%
#f string
price = 59
txt = f"The price is {price} dollars"
print(txt)
# Out:
# The price is 59 dollars

# %% [markdown]
# TYPE CASTING

# %%
a= 10.2
print(a)
b=a
b= int(a)
print (b)
# Out:
# 10.2
# 10

# %% [markdown]
# Data Structure

# %% [markdown]
# used for storing multiple
# types data -homogeneous ,hetrogeneous
# list store hetrogenous data ,
# array store same type data
# Memory organization -non cotinuous , continious
# non-continuous-random

# %% [markdown]
# list- hetrogenous,ordered, mutable ,allow duplication
# touple- hetrogenous, ordered, unmutable

# %%
#list
a=[1,2,4,3]
print(a)
print(type(a))
print(id(a)) # address
b=[1,2,4,3]
print(b)
print(id(b))
# Out:
# [1, 2, 4, 3]
# <class 'list'>
# 133195406732992
# [1, 2, 4, 3]
# 133195406733184

# %%
a=[1,2,4,3]
b=a
print(b)
print(id(b))
# Out:
# [1, 2, 4, 3]
# 133195406731456

# %%
#access list item- for loop and membership
for i in a:
 # print(i)
  print(id(0))
  print(id(1))
  print("or",id(0) or (1))
# Out:
# 11645320
# 11645352
# or 11645320
# 11645320
# 11645352
# or 11645320
# 11645320
# 11645352
# or 11645320
# 11645320
# 11645352
# or 11645320

# %%
for i  in range(1,3):
  print(i)
# Out:
# 1
# 2

# %% [markdown]
# list comprehension existing list se new list created

# %%
fruits = ["apple", "banana", "cherry", "kiwi", "mango"]
newlist = []

for x in fruits:
  if "a" in x:
    newlist.append(x)

print(newlist)
# Out:
# ['apple', 'banana', 'mango']

# %%
#frequency count
a=[1,2,3,4,2,3,4,3,4,1]
print("1 frequency",a.count(1))
print("2 frequency",a.count(2))
print("3 frequency",a.count(3))
print("4 frequency",a.count(4))
# Out:
# 1 frequency 2
# 2 frequency 2
# 3 frequency 3
# 4 frequency 3

# %%
#tuple

t=(1,3,4,5)
print(t)
print(type(t))

t[1]=30
print(t)
# Out:
# (1, 3, 4, 5)
# <class 'tuple'>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_2568/3851216346.py in <cell line: 0>()
#       5 print(type(t))
#       6
# ----> 7 t[1]=30
#       8 print(t)
#       9
#
# TypeError: 'tuple' object does not support item assignment

# %%
#unpack
fruits = ("apple", "banana", "cherry")

(green, yellow, red) = fruits

print(green)
print(yellow)
print(red)
# Out:
# apple
# banana
# cherry

# %% [markdown]
# list and tuple allow duplication , dulication ko  remove krne ke liye set  aaya ,
# using set reove duplication

# %%
a={3,4,5,6,2,4,5}
print(a)
print(sum(a))
# Out:
# {2, 3, 4, 5, 6}
# 20

# %%
#dictionary- ordered
a={
  "name": "simran",
  "year": 2026,
  "Age": 21
}
print(a)
print(a['name'])
# Out:
# {'name': 'simran', 'year': 2026, 'Age': 21}
# simran

# %% [markdown]
# FUNCTION-A function is a block of code which only runs when it is called.

# %%
def my_function():
  print("Hello from a function")

my_function()
# Out:
# Hello from a function

# %%
def greet():
  print("welcome to Nirman")
greet()
greet()
# Out:
# welcome to Nirman
# welcome to Nirman

# %%
def add(x, y):
  print(x + y)
add(3,4)
# Out:
# 7

# %%
#local scope
def myfunc():
  x = 300
  print(x)

myfunc()
print(x)
# Out:
# 300
# 300

# %%
def myfunc():
  global x
  x = 300

myfunc()

print(x)
# Out:
# 300

# %% [markdown]
# STRING METHOD

# %%
txt = "hello, and welcome to my world."

x = txt.capitalize()

print (x)
# Out:
# Hello, and welcome to my world.

# %%
txt = "Hello, And Welcome To My World!"

x = txt.casefold()

print(x)
# Out:
# hello, and welcome to my world!

# %%
txt = "banana"

x = txt.center(20)

print(x)
# Out:
#        banana

# %%
txt = "I love apples,apple apple are my favorite fruit"

x = txt.count("apple")
x = txt.count("apple", 10, 24)

print(x)
# Out:
# 1

# %%
txt = "My name is Ståle"

x = txt.encode()

print(x)
# Out:
# b'My name is St\xc3\xa5le'

# %%
txt = "Hello, welcome to my world."

x = txt.endswith(".")

print(x)
# Out:
# True

# %% [markdown]
# dictionary method

# %%
car = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}

car.pop("model")

print(car)
# Out:
# {'brand': 'Ford', 'year': 1964}

# %%
car = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}

car.clear()

print(car)
# Out:
# {}

# %%
car = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}

x = car.values()

print(x)
# Out:
# dict_values(['Ford', 'Mustang', 1964])

# %%
a = 200
b = 33

if b > a:
  print("b is greater than a")
else:
  print("b is not greater than a")
# Out:
# b is not greater than a

# %%
print(bool("Hello"))
print(bool(15))
# Out:
# True
# True

# %%
print(bool(False))
print(bool(None))
print(bool(0))
print(bool(""))
print(bool(()))
print(bool([]))
print(bool({}))
# Out:
# False
# False
# False
# False
# False
# False
# False

# %% [markdown]
# list comprehension

# %%
fruits = ["apple", "banana", "cherry", "kiwi", "mango"]
newlist = []

for x in fruits:
  if "a" in x:
    newlist.append(x)

print(newlist)
print(fruits)
# Out:
# ['apple', 'banana', 'mango']
# ['apple', 'banana', 'cherry', 'kiwi', 'mango']

# %%
fruits = ["apple", "banana", "cherry", "kiwi", "mango"]

newlist = [x for x in fruits if "a" in x]

print(newlist)
# Out:
# ['apple', 'banana', 'mango']

# %%
thislist = ["orange", "mango", "kiwi", "pineapple", "banana"]
thislist.sort(reverse = True)
print(thislist)
# Out:
# ['pineapple', 'orange', 'mango', 'kiwi', 'banana']

# %%
def myfunc(n):
  return abs(n - 50)

thislist = [100, 50, 65, 82, 23]

thislist.sort(key = myfunc)

print(thislist)
# Out:
# [50, 65, 23, 82, 100]
