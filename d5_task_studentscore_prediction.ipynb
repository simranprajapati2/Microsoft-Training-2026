# %% [markdown]
# <a href="https://colab.research.google.com/github/simranprajapati2/Microsoft-Training-2026/blob/main/d5_task_studentscore_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Student Score pediction

# %%
import pandas as pd

# %%
df=pd.read_csv("/content/Data_score.csv")

# %%
df.head(10)
# Out:
#    Hours  Practice  TeamWork  Scores
# 0    2.5       0.5       0.0      21
# 1    5.1       1.5       0.5      47
# 2    3.2       1.0       0.5      27
# 3    8.5       3.7       1.2      75
# 4    3.5       1.2       0.3      30
# 5    1.5       0.2       0.0      20
# 6    9.2       4.8       3.0      88
# 7    5.5       3.2       2.0      60
# 8    9.3       5.1       3.5      81
# 9    2.7       1.5       0.0      25

# %%
df.isnull().sum()
# Out:
# Hours       0
# Practice    0
# TeamWork    0
# Scores      0
# dtype: int64

# %%
#df1 = df.dropna()

# %%
df.shape
# Out:
# (25, 4)

# %%
import matplotlib.pyplot as plt

# %%
x=df[['Hours']]
y=df['Scores']
plt.scatter(x,y)
plt.show()

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=10)

# %%
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((20, 1), (5, 1), (20,), (5,))

# %%
from sklearn.linear_model import LinearRegression

# %%
x = df[['Hours']]
y = df['Scores']

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=9)

lr=LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr.score(x_train,y_train)*100
# Out:
# 94.61441578452653

# %%
lr.coef_
# Out:
# array([9.62186326])

# %%
lr.intercept_
# Out:
# np.float64(3.5276551279835218)

# %%
lr.predict([[6]])
# Out:
# /usr/local/lib/python3.13/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([61.25883471])

# %%
plt.scatter(x,y)
plt.plot(x,lr.predict(x),color='red')
plt.show()

# %%
from sklearn.metrics import mean_squared_error

# %%
mse=mean_squared_error(y_test,lr.predict(x_test))
print(mse)
# Out:
# 39.07113397322275

# %%
from sklearn.metrics import mean_absolute_error

# %%
mae=mean_absolute_error(y_test,lr.predict(x_test))
print(mae)
# Out:
# 5.523200452538463

# %%
from sklearn.metrics import root_mean_squared_error

# %%
rmse=root_mean_squared_error(y_test,lr.predict(x_test))
print(rmse)
# Out:
# 6.250690679694745

# %%
from sklearn.metrics import r2_score

# %%
r2 = r2_score(y_test,lr.predict(x_test))
print(r2)
# Out:
# 0.9161563648643288

# %%
accuracy=r2*100
print(accuracy)
# Out:
# 91.61563648643288
